# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns

# %%
df = pd.read_csv("TMDB_movie_dataset_v11.csv")

# %%
df.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# 0        Inception  Cobb, a skilled thief who commits corporate es...
# 1     Interstellar  The adventures of a group of explorers who mak...
# 2  The Dark Knight  Batman raises the stakes in his war on crime. ...
# 3           Avatar  In the 22nd century, a paraplegic Marine is di...
# 4     The Avengers  When an unexpected enemy emerges and threatens...
#
#   popularity                       poster_path  \
# 0     83.952  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1    140.241  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2    130.643  /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3     79.932  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4     98.082   /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
#
#                                              tagline  \
# 0               Your mind is the scene of the crime.
# 1  Mankind was born on Earth. It was never meant ...
# 2                  Welcome to a world without rules.
# 3                        Enter the world of Pandora.
# 4                            Some assembly required.
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3  Dune Entertainment, Lightstorm Entertainment, ...
# 4                                     Marvel Studios
#
#                        production_countries  \
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
# 2  United Kingdom, United States of America
# 3  United States of America, United Kingdom
# 4                  United States of America
#
#                      spoken_languages  \
# 0  English, French, Japanese, Swahili
# 1                             English
# 2                   English, Mandarin
# 3                    English, Spanish
# 4             English, Hindi, Russian
#
#                                             keywords
# 0  rescue, mission, dream, airplane, paris, franc...
# 1  rescue, future, spacecraft, race against time,...
# 2  joker, sadism, chaos, secret identity, crime f...
# 3  future, society, culture clash, space travel, ...
# 4  new york city, superhero, shield, based on com...
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1270219 entries, 0 to 1270218
# Data columns (total 24 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1270219 non-null  int64
#  1   title                 1270206 non-null  object
#  2   vote_average          1270219 non-null  float64
#  3   vote_count            1270219 non-null  int64
#  4   status                1270219 non-null  object
#  5   release_date          1024589 non-null  object
#  6   revenue               1270219 non-null  int64
#  7   runtime               1270219 non-null  int64
#  8   adult                 1270219 non-null  bool
#  9   backdrop_path         327068 non-null   object
#  10  budget                1270219 non-null  int64
#  11  homepage              132501 non-null   object
#  12  imdb_id               634344 non-null   object
#  13  original_language     1270219 non-null  object
#  14  original_title        1270206 non-null  object
#  15  overview              993591 non-null   object
#  16  popularity            1270219 non-null  float64
#  17  poster_path           844161 non-null   object
#  18  tagline               177654 non-null   object
#  19  genres                734948 non-null   object
#  20  production_companies  557472 non-null   object
#  21  production_countries  679529 non-null   object
#  22  spoken_languages      702814 non-null   object
#  23  keywords              328250 non-null   object
# dtypes: bool(1), float64(2), int64(5), object(16)
# memory usage: 224.1+ MB

# %%
df.describe()
# Out:
#                  id  vote_average    vote_count       revenue       runtime  \
# count  1.270219e+06  1.270219e+06  1.270219e+06  1.270219e+06  1.270219e+06
# mean   8.162841e+05  1.709548e+00  1.688938e+01  6.565919e+05  4.585500e+01
# std    4.348323e+05  2.941597e+00  3.013530e+02  1.879618e+07  6.124997e+01
# min    2.000000e+00  0.000000e+00  0.000000e+00 -1.200000e+01 -2.800000e+01
# 25%    4.508405e+05  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    8.266850e+05  0.000000e+00  0.000000e+00  0.000000e+00  1.900000e+01
# 75%    1.203584e+06  4.000000e+00  1.000000e+00  0.000000e+00  8.700000e+01
# max    1.528507e+06  1.000000e+01  3.449500e+04  5.000000e+09  1.440000e+04
#
#              budget    popularity
# count  1.270219e+06  1.270219e+06
# mean   2.535063e+05  1.128077e+00
# std    5.180499e+06  7.185013e+00
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  6.000000e-01
# 50%    0.000000e+00  6.000000e-01
# 75%    0.000000e+00  8.400000e-01
# max    1.000000e+09  2.994357e+03

# %%
df.isnull().sum()
# Out:
# id                            0
# title                        13
# vote_average                  0
# vote_count                    0
# status                        0
# release_date             245630
# revenue                       0
# runtime                       0
# adult                         0
# backdrop_path            943151
# budget                        0
# homepage                1137718
# imdb_id                  635875
# original_language             0
# original_title               13
# overview                 276628
# popularity                    0
# poster_path              426058
# tagline                 1092565
# genres                   535271
# production_companies     712747
# production_countries     590690
# spoken_languages         567405
# keywords                 941969
# dtype: int64

# %%
plt.figure(figsize=(14,6))
msno.matrix(df, labels=True, color=(0.2, 0.4, 0.6), fontsize=12)
plt.xticks(rotation=45, ha="right")  # diagonal como en tu imagen
plt.tight_layout()
plt.show()
# Out:
# /var/folders/z3/71dgk3sj49qcbxt2z4y68pkh0000gn/T/ipykernel_19370/240316715.py:4: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
df.dropna(subset=['genres'], inplace=True)

# %%
df.drop(['backdrop_path', 'homepage', 'imdb_id', 'overview', 'tagline', 'poster_path', 'production_companies', 'production_countries','spoken_languages', 'spoken_languages', 'keywords'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 734948 entries, 0 to 1270215
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 734948 non-null  int64
#  1   title              734943 non-null  object
#  2   vote_average       734948 non-null  float64
#  3   vote_count         734948 non-null  int64
#  4   status             734948 non-null  object
#  5   release_date       683787 non-null  object
#  6   revenue            734948 non-null  int64
#  7   runtime            734948 non-null  int64
#  8   adult              734948 non-null  bool
#  9   budget             734948 non-null  int64
#  10  original_language  734948 non-null  object
#  11  original_title     734943 non-null  object
#  12  popularity         734948 non-null  float64
#  13  genres             734948 non-null  object
# dtypes: bool(1), float64(2), int64(5), object(6)
# memory usage: 79.2+ MB

# %%
df.isnull().sum()
# Out:
# id                       0
# title                    5
# vote_average             0
# vote_count               0
# status                   0
# release_date         51161
# revenue                  0
# runtime                  0
# adult                    0
# budget                   0
# original_language        0
# original_title           5
# popularity               0
# genres                   0
# dtype: int64

# %%
plt.figure(figsize=(14,6))
msno.matrix(df, labels=True, color=(0.2, 0.4, 0.6), fontsize=12)
plt.xticks(rotation=45, ha="right")  # diagonal como en tu imagen
plt.tight_layout()
plt.show()
# Out:
# /var/folders/z3/71dgk3sj49qcbxt2z4y68pkh0000gn/T/ipykernel_19370/240316715.py:4: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
df.columns
# Out:
# Index(['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'adult', 'budget', 'original_language',
#        'original_title', 'popularity', 'genres'],
#       dtype='object')

# %%
df.hist(figsize=(12, 8), bins=20, color='skyblue')
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'vote_average'}>,
#         <Axes: title={'center': 'vote_count'}>],
#        [<Axes: title={'center': 'revenue'}>,
#         <Axes: title={'center': 'runtime'}>,
#         <Axes: title={'center': 'budget'}>],
#        [<Axes: title={'center': 'popularity'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
numeric_cols = df.select_dtypes(include=['number']).columns.drop('id')

# %%
sns.boxplot(data=df[numeric_cols], showfliers=False)
# Out:
# <Axes: >

# %%
for col in numeric_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[col], showfliers=False)
    plt.title(f"Boxplot de {col}")
    plt.tight_layout()
    plt.show()
